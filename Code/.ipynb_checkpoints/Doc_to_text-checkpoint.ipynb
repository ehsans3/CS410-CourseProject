# %%
pip install textract

# %%
import textract

# %%
text = textract.process('C:\CS410-CourseProject\Influence of Embedded Material on Natural Frequencies of Double Segment Rotating Disk.docx')

# %%
text
# Out:
# b'Journal of Applied Nonlinear Dynamics\n\n\n\n\n\nhttps://lhscientificpublishing.com/Journals/JAND-Default.aspx\n\n\n\nInfluence of Embedded Material on Natural Frequencies of Double Segment    Rotating Disk\n\nEhsan Sarfaraz\xe2\x80\xa0 and Hamid R. Hamidzadeh\n\nDepartment of Mechanical and Manufacturing Engineering, Tennessee State University, Nashville, TN 37209, USA\n\nSubmission Info\n\nCommunicated by Valentin Afraimovich\n\n\n\n\n\nAbstract\n\nAn analytical method is presented to determine the effect of adding different materials at one of the edges of an annular rotating disk on its in-plane natural frequencies and critical speeds. The proposed analysis is based on the linear in-plane free vibration of a compound disk with material discontinuity, by adopting the two-dimensional plane stress theory. The frequency equation was achieved by satisfying the compatibilities of the displacements and stresses at the interfaces of the different segments. The materials used in each se
# ...

# %%
with open('C:\CS410-CourseProject\Influence of Embedded Material on Natural Frequencies of Double Segment Rotating Disk.txt', 'a') as file:
    file.write(str(text))

# %%
with open('C:\CS410-CourseProject\Influence of Embedded Material on Natural Frequencies of Double Segment Rotating Disk.txt', 'r') as file:
    file_contents = file.read()
    updated_contents_n = file_contents.replace('\\n', '')
    updated_contents_t = updated_contents_n.replace('\\t', '')

with open('C:\CS410-CourseProject\Influence of Embedded Material on Natural Frequencies of Double Segment Rotating Disk.txt', 'w') as file:
      file.write(updated_contents_t)
